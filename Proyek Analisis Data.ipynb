# %% [markdown]
# # Proyek Analisis Data: Food Ingredients and Allergens Dataset
#
# - **Nama:** Ulfiyah Nahdi Pratista
# - **Email:** ulfiyahnhadi@gmail.com
# - **ID Dicoding:** ulfiyahnahdipratista

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana performa penjualan pada platform E-Commerce ?
# - Bagaimana tingkat kepuasan customer terhadap layanan kami?
# - Apa produk yang terlaris dan tidak ?
# - Bulan apa pengeluaran cuetomer terbanyak ?
# - Dimana letak geografis customer terbanyak ?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib
# !pip install unidecode
import unidecode
import matplotlib.image as mpimg
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv('/content/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geo_df = pd.read_csv('/content/geolocation_dataset.csv')
geo_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# ```
# # This is formatted as code
# ```

# %%
order_items = pd.read_csv('/content/order_items_dataset.csv')
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_pay = pd.read_csv('/content/order_payments_dataset.csv')
order_pay.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_rev = pd.read_csv('/content/order_reviews_dataset.csv')
order_rev.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
orders_df = pd.read_csv('/content/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
product_cat = pd.read_csv('/content/product_category_name_translation.csv')
product_cat.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv('/content/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
sellers_df = pd.read_csv('/content/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %%
print('\n', customers_df.info())
print('\n', geo_df.info())
print('\n', order_items.info())
print('\n', order_pay.info())
print('\n', order_rev.info())
print('\n', orders_df.info())
print('\n', product_cat.info())
print('\n', products_df.info())
print('\n', sellers_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52499 entries, 0 to 52498
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  52499 non-null  int64
#  1   geolocation_lat              52499 non-null  float64
#  2   geolocation_lng              52498 non-null  float64
#  3   geolocation_city             52498 non-null  object
#  4   geolocation_state            52498 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.0+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70871 entries, 0 to 70870
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       70871 non-null  object
#  1   customer_id                    70871 non-null  object
#  2   order_status                   70871 non-null  object
#  3   order_purchase_timestamp       70871 non-null  object
#  4   order_approved_at              70753 non-null  object
#  5   order_delivered_carrier_date   69616 non-null  object
#  6   order_delivered_customer_date  68758 non-null  object
#  7   order_estimated_delivery_date  70870 non-null  object
# dtypes: object(8)
# memory usage: 4.3+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB
#
#  None

# %% [markdown]
#  Data null pada setiap DataFrame

# %%
print('\nInfo data null customers:\n', customers_df.isnull().sum())
print('\nInfo data null geolocation:\n', geo_df.isnull().sum())
print('\nInfo data null order items:\n', order_items.isnull().sum())
print('\nInfo data null order payments:\n', order_pay.isnull().sum())
print('\nInfo data null order reviews:\n', order_rev.isnull().sum())
print('\nInfo data null orders:\n', orders_df.isnull().sum())
print('\nInfo data null product category:\n', product_cat.isnull().sum())
print('\nInfo data null products:\n', products_df.isnull().sum())
print('\nInfo data null sellers:\n', sellers_df.isnull().sum())
# Out:
# Info data null customers:
#  customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Info data null geolocation:
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                1
# geolocation_city               1
# geolocation_state              1
# dtype: int64
#
# Info data null order items:
#  order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Info data null order payments:
#  order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Info data null order reviews:
#  review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64
#
# Info data null orders:
#  order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 118
# order_delivered_carrier_date     1255
# order_delivered_customer_date    2113
# order_estimated_delivery_date       1
# dtype: int64
#
# Info data null product category:
#  product_category_name            0
# product_category_name_english    0
# dtype: int64
#
# Info data null products:
#  product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# Info data null sellers:
#  seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# Data duplikat pada setiap DataFrame?

# %%
print('Info data duplikat customers:', customers_df.duplicated().sum())
print('Info data duplikat geolocation:', geo_df.duplicated().sum())
print('Info data duplikat order items:', order_items.duplicated().sum())
print('Info data duplikat order payments:', order_pay.duplicated().sum())
print('Info data duplikat order reviews:', order_rev.duplicated().sum())
print('Info data duplikat orders:', orders_df.duplicated().sum())
print('Info data duplikat product category:', product_cat.duplicated().sum())
print('Info data duplikat products:', products_df.duplicated().sum())
print('Info data duplikat sellers:', sellers_df.duplicated().sum())
# Out:
# Info data duplikat customers: 0
# Info data duplikat geolocation: 22021
# Info data duplikat order items: 0
# Info data duplikat order payments: 0
# Info data duplikat order reviews: 0
# Info data duplikat orders: 0
# Info data duplikat product category: 0
# Info data duplikat products: 0
# Info data duplikat sellers: 0

# %% [markdown]
# Describe data customer :

# %%
print('\nData describe customers:\n', customers_df.describe(include='all'))
print('\nData describe geolocation:\n', geo_df.describe(include='all'))
print('\nData describe order items:\n', order_items.describe(include='all'))
print('\nData describe order payments:\n', order_pay.describe(include='all'))
print('\nData describe order reviews:\n', order_rev.describe(include='all'))
print('\nData describe orders:\n', orders_df.describe(include='all'))
print('\nData describe product category:\n', product_cat.describe(include='all'))
print('\nData describe products:\n', products_df.describe(include='all'))
print('\nData describe sellers:\n', sellers_df.describe(include='all'))
# Out:
# Data describe customers:
#                               customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# count               99441.000000         99441          99441
# unique                       NaN          4119             27
# top                          NaN     sao paulo             SP
# freq                         NaN         15540          41746
# mean                35137.474583           NaN            NaN
# std                 29797.938996           NaN            NaN
# min                  1003.000000           NaN            NaN
# 25%                 11347.000000           NaN            NaN
# 50%                 24416.000000           NaN            NaN
# 75%                 58900.000000           NaN            NaN
# max                 99990.000000           NaN            NaN
#
# Data describe geolocation:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  52499.000000     52499.000000     52498.000000
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                    2198.127774       -23.526550       -46.631630
# std                      743.101068         0.043326         0.044848
# min                     1001.000000       -23.883184       -46.861371
# 25%                     1415.000000       -23.561405       -46.659648
# 50%                     2307.000000       -23.535412       -46.638342
# 75%                     2927.500000       -23.488855       -46.595541
# max                     3388.000000       -23.216648       -46.387234
#
#        geolocation_city geolocation_state
# count             52498             52498
# unique                4                 2
# top           sao paulo                SP
# freq              44507             52497
# mean                NaN               NaN
# std                 NaN               NaN
# min                 NaN               NaN
# 25%                 NaN               NaN
# 50%                 NaN               NaN
# 75%                 NaN               NaN
# max                 NaN               NaN
#
# Data describe order items:
#                                  order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# top     aca2eb7d00ea1a7b8ebd4e68314663af  6560211a19b47992c3666cc44a7e94c0
# freq                                 527                              2033
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         shipping_limit_date          price  freight_value
# count                112650  112650.000000  112650.000000
# unique                93318            NaN            NaN
# top     2017-07-21 18:25:23            NaN            NaN
# freq                     21            NaN            NaN
# mean                    NaN     120.653739      19.990320
# std                     NaN     183.633928      15.806405
# min                     NaN       0.850000       0.000000
# 25%                     NaN      39.900000      13.080000
# 50%                     NaN      74.990000      16.260000
# 75%                     NaN     134.900000      21.150000
# max                     NaN    6735.000000     409.680000
#
# Data describe order payments:
#                                  order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# count          103886.000000  103886.000000
# unique                   NaN            NaN
# top                      NaN            NaN
# freq                     NaN            NaN
# mean                2.853349     154.100380
# std                 2.687051     217.494064
# min                 0.000000       0.000000
# 25%                 1.000000      56.790000
# 50%                 1.000000     100.000000
# 75%                 4.000000     171.837500
# max                24.000000   13664.080000
#
# Data describe order reviews:
#                                 review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# count   99224.000000                11568                  40977
# unique           NaN                 4527                  36159
# top              NaN            Recomendo              Muito bom
# freq             NaN                  423                    230
# mean        4.086421                  NaN                    NaN
# std         1.347579                  NaN                    NaN
# min         1.000000                  NaN                    NaN
# 25%         4.000000                  NaN                    NaN
# 50%         5.000000                  NaN                    NaN
# 75%         5.000000                  NaN                    NaN
# max         5.000000                  NaN                    NaN
#
#        review_creation_date review_answer_timestamp
# count                 99224                   99224
# unique                  636                   98248
# top     2017-12-19 00:00:00     2017-06-15 23:21:05
# freq                    463                       4
# mean                    NaN                     NaN
# std                     NaN                     NaN
# min                     NaN                     NaN
# 25%                     NaN                     NaN
# 50%                     NaN                     NaN
# 75%                     NaN                     NaN
# max                     NaN                     NaN
#
# Data describe orders:
#                                  order_id                       customer_id  \
# count                              70871                             70871
# unique                             70871                             70871
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         70871                    70871                70753
# unique            8                    70573                66151
# top       delivered      2018-08-02 12:05:26  2017-11-07 07:30:38
# freq          68758                        3                    7
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         69616                         68758
# unique                        59896                         68354
# top             2018-05-09 15:48:00           2017-12-02 00:26:45
# freq                             30                             3
#
#        order_estimated_delivery_date
# count                          70870
# unique                           454
# top              2018-05-29 00:00:00
# freq                             384
#
# Data describe product category:
#         product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1
#
# Data describe products:
#                                product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# unique                  NaN                         NaN                 NaN
# top                     NaN                         NaN                 NaN
# freq                    NaN                         NaN                 NaN
# mean              48.476949                  771.495285            2.188986
# std               10.245741                  635.115225            1.736766
# min                5.000000                    4.000000            1.000000
# 25%               42.000000                  339.000000            1.000000
# 50%               51.000000                  595.000000            1.000000
# 75%               57.000000                  972.000000            3.000000
# max               76.000000                 3992.000000           20.000000
#
#         product_weight_g  product_length_cm  product_height_cm  \
# count       32949.000000       32949.000000       32949.000000
# unique               NaN                NaN                NaN
# top                  NaN                NaN                NaN
# freq                 NaN                NaN                NaN
# mean         2276.472488          30.815078          16.937661
# std          4282.038731          16.914458          13.637554
# min             0.000000           7.000000           2.000000
# 25%           300.000000          18.000000           8.000000
# 50%           700.000000          25.000000          13.000000
# 75%          1900.000000          38.000000          21.000000
# max         40425.000000         105.000000         105.000000
#
#         product_width_cm
# count       32949.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean           23.196728
# std            12.079047
# min             6.000000
# 25%            15.000000
# 50%            20.000000
# 75%            30.000000
# max           118.000000
#
# Data describe sellers:
#                                 seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# unique           23
# top              SP
# freq           1849
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52499 entries, 0 to 52498
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  52499 non-null  int64
#  1   geolocation_lat              52499 non-null  float64
#  2   geolocation_lng              52498 non-null  float64
#  3   geolocation_city             52498 non-null  object
#  4   geolocation_state            52498 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Duplikat data terdapat pada Geolocation dataset,maka dari itu drop duplikat tidak dilakukan. Value pada kolom 'geolocation_city', 'geolocation_state' value tertinggi adalah sao paulo (SP)

# %%
order_rev[order_rev.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4                  NaN
# 1                 5                  NaN
# 2                 5                  NaN
# 3                 5                  NaN
# 4                 5                  NaN
# ...             ...                  ...
# 99219             5                  NaN
# 99220             5                  NaN
# 99221             5                  NaN
# 99222             4                  NaN
# 99223             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99219                                                NaN  2018-07-07 00:00:00
# 99220                                                NaN  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                                NaN  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49
#
# [87656 rows x 7 columns]

# %%
order_rev.review_comment_title.value_counts()
# Out:
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: review_comment_title, Length: 4527, dtype: int64

# %%
order_rev[order_rev.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# 0                 4                  NaN                    NaN
# 1                 5                  NaN                    NaN
# 2                 5                  NaN                    NaN
# 5                 1                  NaN                    NaN
# 6                 5                  NaN                    NaN
# ...             ...                  ...                    ...
# 99217             5                  NaN                    NaN
# 99218             5                  NaN                    NaN
# 99219             5                  NaN                    NaN
# 99220             5                  NaN                    NaN
# 99222             4                  NaN                    NaN
#
#       review_creation_date review_answer_timestamp
# 0      2018-01-18 00:00:00     2018-01-18 21:46:59
# 1      2018-03-10 00:00:00     2018-03-11 03:05:13
# 2      2018-02-17 00:00:00     2018-02-18 14:36:24
# 5      2018-04-13 00:00:00     2018-04-16 00:39:37
# 6      2017-07-16 00:00:00     2017-07-18 19:30:34
# ...                    ...                     ...
# 99217  2017-12-13 00:00:00     2017-12-14 11:09:36
# 99218  2018-04-27 00:00:00     2018-04-30 01:18:57
# 99219  2018-07-07 00:00:00     2018-07-14 17:18:30
# 99220  2017-12-09 00:00:00     2017-12-11 20:06:42
# 99222  2018-07-01 00:00:00     2018-07-02 12:59:13
#
# [58247 rows x 7 columns]

# %%
order_rev.review_comment_message.value_counts()
# Out:
# Muito bom                                                                                                                                                                                              230
# Bom                                                                                                                                                                                                    189
# muito bom                                                                                                                                                                                              122
# bom                                                                                                                                                                                                    107
# Recomendo                                                                                                                                                                                              100
#                                                                                                                                                                                                       ...
# PRODUTO FOI ENTREGUE VIA CORREIOS\r\nANTES DO PRAZO PREVISTO.                                                                                                                                            1
# Devido incompatibilidade vou devolver, ótimo produto!                                                                                                                                                    1
# Infelizmente não! A qualidade do produto não agradou.Impressão da foto em exposição remete a um tamanho maior e a recebida sequer atende a uma criança. PRODUTO NÃO JUSTIFICA O VALOR INFELIZMENTE!      1
# entrega na data prevista,somente a qualidade do material não é o mesmo que eu pensava mas pelo preço ta valido                                                                                           1
# meu produto chegou e ja tenho que devolver, pois está com defeito , não segurar carga                                                                                                                    1
# Name: review_comment_message, Length: 36159, dtype: int64

# %%
order_rev.fillna(value="no comment", inplace=True)

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 67697  88083e8f64d95b932164187484d90212  f67cd1a215aae2a1074638bbd35a223a
# 68373  b059ee4de278302d550a3035c4cdb740  856336203359aa6a61bf3826f7d84c49
# 68973  0623dbbd06c0d4059dbfefab8748a491  c954645fa23249e4c2b0dd3679b0b177
# 70016  c49e86b525c30f1b55eaf9abbc9837a6  8fa9f17f7cc7af41d068b9b3f8df51e8
# 70384  dbe2d1c6c34f5c31bb6736e1720c9b7e  3b5cb25012ce1400dbf62ed0995e1c14
#
#       order_status order_purchase_timestamp order_approved_at  \
# 1130      canceled      2018-08-28 15:26:39               NaN
# 1801      canceled      2018-09-20 13:54:16               NaN
# 1868      canceled      2017-03-04 12:14:30               NaN
# 2029      canceled      2018-08-29 16:27:49               NaN
# 2161      canceled      2017-05-01 16:12:39               NaN
# ...            ...                      ...               ...
# 67697    delivered      2017-02-18 22:49:19               NaN
# 68373     canceled      2018-10-16 20:16:02               NaN
# 68973     canceled      2018-08-20 14:17:09               NaN
# 70016     canceled      2017-12-06 19:29:14               NaN
# 70384     canceled      2018-08-28 12:45:15               NaN
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 1130                           NaN                           NaN
# 1801                           NaN                           NaN
# 1868                           NaN                           NaN
# 2029                           NaN                           NaN
# 2161                           NaN                           NaN
# ...                            ...                           ...
# 67697          2017-02-22 11:31:06           2017-03-02 12:06:06
# 68373                          NaN                           NaN
# 68973                          NaN                           NaN
# 70016                          NaN                           NaN
# 70384                          NaN                           NaN
#
#       order_estimated_delivery_date
# 1130            2018-09-12 00:00:00
# 1801            2018-10-17 00:00:00
# 1868            2017-04-10 00:00:00
# 2029            2018-09-13 00:00:00
# 2161            2017-05-30 00:00:00
# ...                             ...
# 67697           2017-03-21 00:00:00
# 68373           2018-11-12 00:00:00
# 68973           2018-09-12 00:00:00
# 70016           2018-01-04 00:00:00
# 70384           2018-09-03 00:00:00
#
# [118 rows x 8 columns]

# %%
datetime_oi = ["shipping_limit_date"]
for column in datetime_oi:
  order_items[column] = pd.to_datetime(order_items[column])

# %%
datetime_or = ["review_creation_date","review_answer_timestamp"]

for column in datetime_or:
  order_rev[column] = pd.to_datetime(order_rev[column])

# %%
datetime_oo = ["order_purchase_timestamp","order_approved_at","order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date"]

for column in datetime_oo:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70871 entries, 0 to 70870
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       70871 non-null  object
#  1   customer_id                    70871 non-null  object
#  2   order_status                   70871 non-null  object
#  3   order_purchase_timestamp       70871 non-null  datetime64[ns]
#  4   order_approved_at              70753 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   69616 non-null  datetime64[ns]
#  6   order_delivered_customer_date  68758 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  70870 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 4.3+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### **Explore customer_df**

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 33593  154efa2b11fd0b55befb35a1e65b433a  36bf34be1247a33988a1510f255f6917
# 46706  4785457a74ce730e32aeb085b9dc08d9  c4d7513f13d600e335a6a34f071fbd37
# 28445  a12ac3fe0ed76458dba0379ffd5fa972  091a9495963cef2bbb8d614c9a03721b
# 23565  02c61d2bc19f626c10dd080efe7ecfde  9ff09ff905778a260bafadfafa84bd1b
# 38093  b8314bd695a1b3373a6f434d3d7caac6  6bd41f0cf93d8d32bac60b824e5370e8
#
#        customer_zip_code_prefix customer_city customer_state
# 33593                     17014         bauru             SP
# 46706                     37200        lavras             MG
# 28445                     97501    uruguaiana             RS
# 23565                     82220      curitiba             PR
# 38093                     99670    ronda alta             RS

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# count               99441.000000         99441          99441
# unique                       NaN          4119             27
# top                          NaN     sao paulo             SP
# freq                         NaN         15540          41746
# mean                35137.474583           NaN            NaN
# std                 29797.938996           NaN            NaN
# min                  1003.000000           NaN            NaN
# 25%                 11347.000000           NaN            NaN
# 50%                 24416.000000           NaN            NaN
# 75%                 58900.000000           NaN            NaN
# max                 99990.000000           NaN            NaN

# %%
customers_df.customer_id.is_unique
# Out:
# True

# %%
customers_df.customer_id.duplicated
# Out:
# <bound method Series.duplicated of 0        06b8999e2fba1a1fbc88172c00ba8bc7
# 1        18955e83d337fd6b2def6b18a428ac77
# 2        4e7b3e00288586ebd08712fdd0374a03
# 3        b2b6027bc5c5109e529d4dc6358b12c3
# 4        4f2d8ab171c80ec8364f7c12e35b23ad
#                        ...
# 99436    17ddf5dd5d51696bb3d7c6291687be6f
# 99437    e7b71a9017aa05c9a7fd292d714858e8
# 99438    5e28dfe12db7fb50a4b2f691faecea5e
# 99439    56b18e2166679b8a959d72dd06da27f9
# 99440    274fa6071e5e17fe303b9748641082c8
# Name: customer_id, Length: 99441, dtype: object>

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %%
order_pay.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 41839  db398b78388fa1c67b3a505ea123c001                   2      voucher
# 60378  42a64eac09d0a6be5a307753093d45e8                   1  credit_card
# 29565  a5fc3fd8cb616492cc41918cb96a5fe2                   1  credit_card
# 47465  a8666b29dbc635b3a029b1ed84fa8df5                   3      voucher
# 41663  1c11d0f4353b31ac3417fbfa5f0f2a8a                   3      voucher
#
#        payment_installments  payment_value
# 41839                     1          50.00
# 60378                     2         112.14
# 29565                     1          62.74
# 47465                     1          33.44
# 41663                     1         200.00

# %%
order_pay.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# count          103886.000000  103886.000000
# unique                   NaN            NaN
# top                      NaN            NaN
# freq                     NaN            NaN
# mean                2.853349     154.100380
# std                 2.687051     217.494064
# min                 0.000000       0.000000
# 25%                 1.000000      56.790000
# 50%                 1.000000     100.000000
# 75%                 4.000000     171.837500
# max                24.000000   13664.080000

# %%
order_pay.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 64375  33401d2d0621ceae77505c91308ceddd  3fcda70d69c185780fb4abd140ba69e3
# 9388   206936fdf08a1d23122f1d36c4e0e064  810c7bae3b3fe36cbc666dec01471292
# 61216  f1ea8b66e6bceacb9d56a84505f36dd1  ebfded4f6875004a5b269c5683a64ab3
# 23955  95edd52b3452d4069b0fbc8056f01daa  f6917e239b9f9f34309ae169d4adf084
# 9651   ea2a61e3a57414402f9c6dae7b04cddd  06fbbb4b3c723e6f7023671729bdbb4e
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 64375    delivered      2018-01-23 10:26:00 2018-01-23 10:35:18
# 9388     delivered      2017-06-29 20:46:04 2017-07-01 05:04:00
# 61216    delivered      2018-02-13 18:45:25 2018-02-13 18:55:34
# 23955    delivered      2018-05-03 22:12:32 2018-05-03 22:52:43
# 9651     delivered      2017-08-11 11:21:31 2017-08-12 02:55:38
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 64375          2018-01-24 08:15:41           2018-01-30 19:39:09
# 9388           2017-07-03 14:53:44           2017-07-08 14:31:58
# 61216          2018-02-15 19:46:10           2018-03-02 18:29:02
# 23955          2018-05-04 17:23:00           2018-05-07 21:28:55
# 9651           2017-08-15 19:52:00           2017-08-17 17:23:53
#
#       order_estimated_delivery_date
# 64375                    2018-02-19
# 9388                     2017-07-24
# 61216                    2018-03-13
# 23955                    2018-05-17
# 9651                     2017-08-31

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_delivered_carrier_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 57260  9c8b3e3a0c6ba4c5497158fe7aa2a1d6  dd0329246296428beec510ea36313e31
# 15832  9635ce9faca001ffd1c913c8e55deaed  4541fb6085235c60a37508989a808894
# 51957  19421091ea8830b487a1aa4c43e074b6  5b444fe93863147c86213fe089495d05
# 31789  1946c4925cef4f63c6d90302b3d8caf4  c70d51086d1a00d014cec2e4a2aeea5f
# 56399  4e233b40b72c7a074309dc423a0320e6  2d3488b51dd898ee2b4d0eabdcf85855
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 57260    delivered      2017-11-16 12:13:06 2017-11-16 13:15:59
# 15832    delivered      2017-11-24 10:12:09 2017-11-24 10:31:47
# 51957    delivered      2017-03-23 22:36:21 2017-03-23 22:50:19
# 31789    delivered      2017-07-09 15:01:59 2017-07-09 15:10:13
# 56399    delivered      2018-06-20 21:04:58 2018-06-22 03:17:18
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 57260          2017-11-21 23:52:12           2017-11-22 17:23:50
# 15832          2017-11-24 18:57:07           2017-11-25 19:24:49
# 51957          2017-03-27 14:48:50           2017-04-06 15:45:57
# 31789          2017-07-18 22:47:01           2017-07-20 15:59:35
# 56399          2018-06-22 13:17:00           2018-06-27 19:04:45
#
#       order_estimated_delivery_date  delivery_time
# 57260                    2017-12-19            1.0
# 15832                    2017-12-12            1.0
# 51957                    2017-04-18           10.0
# 31789                    2017-07-21            2.0
# 56399                    2018-07-18            5.0

# %%
orders_df.delivery_time.hist()
# Out:
# <Axes: >

# %%
# Extracting customer IDs from orders_df
customer_id_in_orders_df = orders_df.customer_id.values

# Applying the lambda function to label customers as "Active" or "Non Active"
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")

# Displaying a sample of 5 rows from customers_df
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 24184  c92cbf323a2d0bcfd0cbd1032cdbb166  d05f55a2a87d03910009d1360c3b7ef3
# 4056   8d53cffa847c8c98fc003386511020eb  7f4d4d150d120fe0dd56f11866a63f36
# 86597  32fa500a4e324c15904b33f89ec561c4  3968dd0baa7f020cfbdd98aacf602c42
# 85271  84b5d5ec2e4c5409eb6d9ed090499a80  e95546f329e86a4c7c5f1ecba299d90e
# 89739  d750ae01f955a2ee39b07ad92760cbc0  4c2fff3d2df31cd85717420a7cf590da
#
#        customer_zip_code_prefix  customer_city customer_state      status
# 24184                     87390  boa esperanca             PR  Non Active
# 4056                       5890      sao paulo             SP      Active
# 86597                     13486        limeira             SP  Non Active
# 85271                      7161      guarulhos             SP      Active
# 89739                     43700   simoes filho             BA      Active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        70871
# Non Active    28570
# Name: customer_id, dtype: int64

# %% [markdown]
# **Merge customers_df & orders_df**

# %%
cust_orders_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
cust_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state      status  \
# 0                     14409                 franca             SP  Non Active
# 1                      9790  sao bernardo do campo             SP  Non Active
# 2                      1151              sao paulo             SP      Active
# 3                      8775        mogi das cruzes             SP      Active
# 4                     13056               campinas             SP      Active
#
#                            order_id order_status order_purchase_timestamp  \
# 0                               NaN          NaN                      NaT
# 1                               NaN          NaN                      NaT
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#     order_approved_at order_delivered_carrier_date  \
# 0                 NaT                          NaT
# 1                 NaT                          NaT
# 2 2018-05-20 16:19:10          2018-06-11 14:31:00
# 3 2018-03-13 17:29:19          2018-03-27 23:22:42
# 4 2018-07-29 10:10:09          2018-07-30 15:16:00
#
#   order_delivered_customer_date order_estimated_delivery_date  delivery_time
# 0                           NaT                           NaT            NaN
# 1                           NaT                           NaT            NaN
# 2           2018-06-14 17:58:51                    2018-06-13            3.0
# 3           2018-03-28 16:04:25                    2018-04-10            1.0
# 4           2018-08-09 20:55:48                    2018-08-15           10.0

# %%
cust_orders_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                10937
# rio de janeiro            4978
# belo horizonte            1969
# brasilia                  1492
# curitiba                  1079
# campinas                  1024
# porto alegre               977
# salvador                   891
# guarulhos                  856
# sao bernardo do campo      688
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    29709
# RJ     9229
# MG     8233
# RS     3883
# PR     3565
# SC     2641
# BA     2440
# DF     1498
# GO     1447
# ES     1441
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="customer_zip_code_prefix").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_zip_code_prefix
# 22790    100
# 24220     96
# 22793     85
# 24230     76
# 22775     75
# 29101     74
# 22631     73
# 13212     72
# 35500     65
# 11065     65
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# order_status
# delivered      68758
# shipped          809
# canceled         449
# unavailable      428
# processing       212
# invoiced         209
# created            5
# approved           1
# Name: order_id, dtype: int64

# %% [markdown]
# **Merge order_pay & order_rev**

# %%
order_payrev_df = pd.merge(
    left=order_pay,
    right=order_rev,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_payrev_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# 1           5.0           no comment
# 2           5.0           no comment
# 3           5.0           no comment
# 4           5.0           no comment
#
#                               review_comment_message review_creation_date  \
# 0  Produto com qualidade ruim, amassado e descasc...           2018-05-10
# 1                                         no comment           2018-06-30
# 2                                           Aprovada           2017-12-19
# 3                                         no comment           2017-12-21
# 4                                         no comment           2017-12-21
#
#   review_answer_timestamp
# 0     2018-05-15 23:38:00
# 1     2018-07-03 11:23:16
# 2     2017-12-22 17:55:30
# 3     2017-12-21 21:42:31
# 4     2017-12-22 01:10:39

# %%
order_payrev_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
order_payrev_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# **Merge cust_orders_df & order_payrev**

# %%
customers_df = pd.merge(
    left=cust_orders_df,
    right=order_payrev_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state      status  \
# 0                     14409                 franca             SP  Non Active
# 1                      9790  sao bernardo do campo             SP  Non Active
# 2                      1151              sao paulo             SP      Active
# 3                      8775        mogi das cruzes             SP      Active
# 4                     13056               campinas             SP      Active
#
#                            order_id order_status order_purchase_timestamp  \
# 0                               NaN          NaN                      NaT
# 1                               NaN          NaN                      NaT
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#     order_approved_at  ... payment_sequential payment_type  \
# 0                 NaT  ...                NaN          NaN
# 1                 NaT  ...                NaN          NaN
# 2 2018-05-20 16:19:10  ...                1.0  credit_card
# 3 2018-03-13 17:29:19  ...                1.0  credit_card
# 4 2018-07-29 10:10:09  ...                1.0  credit_card
#
#   payment_installments  payment_value                         review_id  \
# 0                  NaN            NaN                               NaN
# 1                  NaN            NaN                               NaN
# 2                  7.0         157.73  5ad6695d76ee186dc473c42706984d87
# 3                  1.0         173.30  059a801bb31f6aab2266e672cab87bc5
# 4                  8.0         252.25  8490879d58d6c5d7773f2739a03f089a
#
#   review_score  review_comment_title  \
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          5.0            no comment
# 3          5.0            no comment
# 4          5.0         a melhor nota
#
#                           review_comment_message review_creation_date  \
# 0                                            NaN                  NaT
# 1                                            NaN                  NaT
# 2                                     no comment           2018-06-15
# 3                                     no comment           2018-03-29
# 4  O baratheon è esxelente Amo adoro o baratheon           2018-08-10
#
#    review_answer_timestamp
# 0                      NaT
# 1                      NaT
# 2      2018-06-15 12:10:59
# 3      2018-04-02 18:36:47
# 4      2018-08-17 01:59:52
#
# [5 rows x 24 columns]

# %% [markdown]
# #Exploreorder_items & sellers_df

# %% [markdown]
# **Merge order_items & sellers_df**

# %%
item_seller_df = pd.merge(
    left=order_items,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
item_seller_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# 2 2018-01-18 14:48:30  199.00          17.87                   37564
# 3 2018-08-15 10:10:18   12.99          12.79                   14403
# 4 2017-02-13 13:57:51  199.90          18.14                   87900
#
#      seller_city seller_state
# 0  volta redonda           SP
# 1      sao paulo           SP
# 2  borda da mata           MG
# 3         franca           SP
# 4         loanda           PR

# %%
item_seller_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %% [markdown]
# #Explore products_df & product_cat

# %% [markdown]
# **Merge products_df & product_cat**

# %%
product_df = pd.merge(
    left=products_df,
    right=product_cat,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %%
product_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
product_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# **Merge item_seller_df & product_df**

# %%
sellers_df = pd.merge(
    left=product_df,
    right=item_seller_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sellers_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
#
#   product_category_name_english                          order_id  \
# 0                     perfumery  e17e4f88e31525f7deef66779844ddce
# 1                           art  5236307716393b7114b53ee991f36956
# 2                sports_leisure  01f66e58769f84129811d43eefd187fb
# 3                          baby  143d00a4f2dde4e0364ee1821577adb3
# 4                    housewares  86cafb8794cb99a9b1b77fc8e48fbbbb
#
#    order_item_id                         seller_id shipping_limit_date  \
# 0              1  5670f4db5b62c43d542e1b2d56b0cf7c 2018-04-30 17:33:54
# 1              1  b561927807645834b59ef0d16ba55a24 2018-02-06 19:11:15
# 2              1  7b07b3c7487f0ea825fc6df75abd658b 2018-07-11 21:30:20
# 3              1  c510bc1718f0f2961eaa42a23330681a 2018-08-07 09:10:13
# 4              1  0be8ff43f22e456b4e0371b2245e4d01 2018-04-17 01:30:23
#
#     price  freight_value  seller_zip_code_prefix seller_city seller_state
# 0   10.91           7.39                    3694   sao paulo           SP
# 1  248.00          17.99                    2955   sao paulo           SP
# 2   79.80           7.82                    2016   sao paulo           SP
# 3  112.30           9.54                   13330  indaiatuba           SP
# 4   37.90           8.29                    4461   sao paulo           SP

# %%
sellers_df.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20528  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 73922  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 49503  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 71835  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 32232  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 55911  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55903  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 29610  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29608  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29609  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 20528                 31.0                       875.0                 2.0
# 73922                 50.0                      1935.0                 4.0
# 49503                 28.0                      3954.0                 2.0
# 71835                 41.0                      1780.0                 2.0
# 32232                 59.0                      2217.0                 2.0
# ...                    ...                         ...                 ...
# 55911                 45.0                       231.0                 3.0
# 55903                 45.0                       231.0                 3.0
# 29610                 25.0                      1041.0                 5.0
# 29608                 25.0                      1041.0                 5.0
# 29609                 25.0                      1041.0                 5.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 20528           30000.0               60.0               61.0
# 73922            5660.0               54.0               18.0
# 49503            7400.0               47.0               25.0
# 71835           22600.0               55.0               40.0
# 32232           30000.0               50.0               49.0
# ...                 ...                ...                ...
# 55911             800.0               21.0                4.0
# 55903             800.0               21.0                4.0
# 29610             200.0               16.0                4.0
# 29608             200.0               16.0                4.0
# 29609             200.0               16.0                4.0
#
#        product_width_cm    product_category_name_english  \
# 20528              33.0                       housewares
# 73922              47.0                        computers
# 49503              25.0                              art
# 71835              40.0                 small_appliances
# 32232              50.0                 small_appliances
# ...                 ...                              ...
# 55911              15.0                    health_beauty
# 55903              15.0                    health_beauty
# 29610              11.0  construction_tools_construction
# 29608              11.0  construction_tools_construction
# 29609              11.0  construction_tools_construction
#
#                                order_id  order_item_id  \
# 20528  0812eb902a67711a1cb742b3cdaa65ae              1
# 73922  fefacc66af859508bf1a7934eab1e97f              1
# 49503  f5136e38d1a14a4dbd87dff67da82701              1
# 71835  a96610ab360d42a2e5335a3998b4718a              1
# 32232  199af31afc78c699f0dbf71fb178d4d4              1
# ...                                 ...            ...
# 55911  8272b63d03f5f79c56e9e4120aec44ef             11
# 55903  8272b63d03f5f79c56e9e4120aec44ef              3
# 29610  c5bdd8ef3c0ec420232e668302179113              2
# 29608  3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 29609  6e864b3f0ec71031117ad4cf46b7f2a1              1
#
#                               seller_id shipping_limit_date    price  \
# 20528  e3b4998c7a498169dc7bce44e6bb6277 2017-02-16 20:37:36  6735.00
# 73922  80ceebb4ee9b31afb6c6a916a574a1e2 2018-08-02 04:05:13  6729.00
# 49503  ee27a8f15b1dded4d213a468ba4eb391 2017-06-15 02:45:17  6499.00
# 71835  59417c56835dd8e2e72f91f809cd4092 2017-04-18 13:25:18  4799.00
# 32232  59417c56835dd8e2e72f91f809cd4092 2017-05-09 15:50:15  4690.00
# ...                                 ...                 ...      ...
# 55911  2709af9587499e95e803a6498a5a56e9 2017-07-21 18:25:23     1.20
# 55903  2709af9587499e95e803a6498a5a56e9 2017-07-21 18:25:23     1.20
# 29610  96804ea39d96eb908e7c3afdb671bb9e 2018-05-07 02:55:22     0.85
# 29608  96804ea39d96eb908e7c3afdb671bb9e 2018-05-04 03:55:26     0.85
# 29609  96804ea39d96eb908e7c3afdb671bb9e 2018-05-02 20:30:34     0.85
#
#        freight_value  seller_zip_code_prefix seller_city seller_state
# 20528         194.31                    3635   sao paulo           SP
# 73922         193.21                   86026    londrina           PR
# 49503         227.66                   74210     goiania           GO
# 71835         151.34                   13480     limeira           SP
# 32232          74.34                   13480     limeira           SP
# ...              ...                     ...         ...          ...
# 55911           7.89                    3813   sao paulo           SP
# 55903           7.89                    3813   sao paulo           SP
# 29610          22.30                   38950        ibia           MG
# 29608          18.23                   38950        ibia           MG
# 29609          18.23                   38950        ibia           MG
#
# [112650 rows x 19 columns]

# %%
sellers_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# **Explore geo_df**

# %%
geo_df.sample(5)
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 20077                         2055       -23.513906       -46.604587
# 33483                         2516       -23.507408       -46.660948
# 40921                         2916       -23.501969       -46.700491
# 5711                          1240       -23.541468       -46.662141
# 48396                         3139       -23.584980       -46.577398
#
#       geolocation_city geolocation_state
# 20077        são paulo                SP
# 33483        sao paulo                SP
# 40921        sao paulo                SP
# 5711         são paulo                SP
# 48396        sao paulo                SP

# %%
def pretty_string(column):
    column_space = ' '.join(column.split())
    return unidecode.unidecode(column_space.lower())

# %%
geo_df['geolocation_city'] = geo_df['geolocation_city'].apply(pretty_string)

# %%
geo_df.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 1415    319
# 1307    311
# 1311    309
# 1403    281
# 2435    272
#        ...
# 3347      1
# 2888      1
# 3036      1
# 3351      1
# 3388      1
# Length: 1231, dtype: int64

# %%
geo_df[geo_df['geolocation_zip_code_prefix'] == 24220].head()
# Out:
# Empty DataFrame
# Columns: [geolocation_zip_code_prefix, geolocation_lat, geolocation_lng, geolocation_city, geolocation_state]
# Index: []

# %% [markdown]
# #Explore All Data
# **Merge all data**
#
# Pada proyek ini tidak ada penggabungan dataset geolocation, karena dataset ini tidak terlalu diperlukan.

# %%
all_data = pd.merge(
    left=customers_df,
    right=sellers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_data.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state      status  \
# 0                     14409                 franca             SP  Non Active
# 1                      9790  sao bernardo do campo             SP  Non Active
# 2                      1151              sao paulo             SP      Active
# 3                      8775        mogi das cruzes             SP      Active
# 4                     13056               campinas             SP      Active
#
#                            order_id order_status order_purchase_timestamp  \
# 0                               NaN          NaN                      NaT
# 1                               NaN          NaN                      NaT
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#     order_approved_at  ... product_width_cm product_category_name_english  \
# 0                 NaT  ...              NaN                           NaN
# 1                 NaT  ...              NaN                           NaN
# 2 2018-05-20 16:19:10  ...             17.0              office_furniture
# 3 2018-03-13 17:29:19  ...             28.0              office_furniture
# 4 2018-07-29 10:10:09  ...             35.0                  home_confort
#
#   order_item_id                         seller_id  shipping_limit_date  \
# 0           NaN                               NaN                  NaT
# 1           NaN                               NaN                  NaT
# 2           1.0  7c67e1448b00f6e969d365cea6b010ab  2018-06-05 16:19:10
# 3           1.0  7c67e1448b00f6e969d365cea6b010ab  2018-03-27 16:31:16
# 4           1.0  4a3ca9315b744ce9f8e9374361493884  2018-07-31 10:10:09
#
#     price  freight_value  seller_zip_code_prefix      seller_city  \
# 0     NaN            NaN                     NaN              NaN
# 1     NaN            NaN                     NaN              NaN
# 2  139.94          17.79                  8577.0  itaquaquecetuba
# 3  149.94          23.36                  8577.0  itaquaquecetuba
# 4  230.00          22.25                 14940.0         ibitinga
#
#    seller_state
# 0           NaN
# 1           NaN
# 2            SP
# 3            SP
# 4            SP
#
# [5 rows x 42 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113308 entries, 0 to 113307
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    113308 non-null  object
#  1   customer_unique_id             113308 non-null  object
#  2   customer_zip_code_prefix       113308 non-null  int64
#  3   customer_city                  113308 non-null  object
#  4   customer_state                 113308 non-null  object
#  5   status                         113308 non-null  object
#  6   order_id                       84738 non-null   object
#  7   order_status                   84738 non-null   object
#  8   order_purchase_timestamp       84738 non-null   datetime64[ns]
#  9   order_approved_at              84606 non-null   datetime64[ns]
#  10  order_delivered_carrier_date   83254 non-null   datetime64[ns]
#  11  order_delivered_customer_date  82273 non-null   datetime64[ns]
#  12  order_estimated_delivery_date  84737 non-null   datetime64[ns]
#  13  delivery_time                  82273 non-null   float64
#  14  payment_sequential             84735 non-null   float64
#  15  payment_type                   84735 non-null   object
#  16  payment_installments           84735 non-null   float64
#  17  payment_value                  84735 non-null   float64
#  18  review_id                      84046 non-null   object
#  19  review_score                   84046 non-null   float64
#  20  review_comment_title           84046 non-null   object
#  21  review_comment_message         84046 non-null   object
#  22  review_creation_date           84046 non-null   datetime64[ns]
#  23  review_answer_timestamp        84046 non-null   datetime64[ns]
#  24  product_id                     84142 non-null   object
#  25  product_category_name          82928 non-null   object
#  26  product_name_lenght            82928 non-null   float64
#  27  product_description_lenght     82928 non-null   float64
#  28  product_photos_qty             82928 non-null   float64
#  29  product_weight_g               84126 non-null   float64
#  30  product_length_cm              84126 non-null   float64
#  31  product_height_cm              84126 non-null   float64
#  32  product_width_cm               84126 non-null   float64
#  33  product_category_name_english  82911 non-null   object
#  34  order_item_id                  84142 non-null   float64
#  35  seller_id                      84142 non-null   object
#  36  shipping_limit_date            84142 non-null   datetime64[ns]
#  37  price                          84142 non-null   float64
#  38  freight_value                  84142 non-null   float64
#  39  seller_zip_code_prefix         84142 non-null   float64
#  40  seller_city                    84142 non-null   object
#  41  seller_state                   84142 non-null   object
# dtypes: datetime64[ns](8), float64(16), int64(1), object(17)
# memory usage: 37.2+ MB

# %%
all_data.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                     price  freight_value
# customer_city       product_category_name_english
# abadia dos dourados cool_stuff                     199.00          20.63
# abadiania           small_appliances               949.99          75.53
# abaete              baby                            65.00          17.70
#                     bed_bath_table                 105.90          17.99
#                     cool_stuff                      85.99          23.40
# ...                                                   ...            ...
# xique-xique         bed_bath_table                  40.99          16.79
#                     computers_accessories           31.90          16.79
# zacarias            housewares                      55.00          13.41
# ze doca             garden_tools                    39.90          26.61
#                     musical_instruments            359.00          49.04
#
# [20345 rows x 2 columns]

# %%
all_data.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                 price  freight_value
# customer_state product_category_name_english
# AC             auto                            561.97         104.04
#                baby                            309.84         136.05
#                bed_bath_table                  567.70         157.51
#                books_general_interest          524.90          70.59
#                christmas_supplies               69.90          60.95
# ...                                               ...            ...
# TO             sports_leisure                 2571.85         773.03
#                stationery                      246.90          46.91
#                telephony                       796.78         445.06
#                toys                           1127.39         249.53
#                watches_gifts                  2867.73         592.56
#
# [1280 rows x 2 columns]

# %%
all_data.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 29709     5362975.30
# RJ                  9229     2060891.54
# MG                  8233     1664809.83
# RS                  3883      835195.97
# PR                  3565      798349.11
# BA                  2440      594888.31
# SC                  2641      558536.68
# GO                  1447      358759.30
# DF                  1498      299686.43
# ES                  1441      297020.52
# PE                  1198      279512.19
# CE                   968      259930.35
# PA                   709      193201.51
# MT                   638      191535.25
# MA                   540      153178.59
# PB                   381      139587.81
# MS                   529      129740.18
# PI                   348       88239.68
# RN                   325       82989.89
# AL                   292       81376.90
# SE                   249       69487.50
# RO                   177       46481.75
# TO                   187       44132.80
# AM                    96       20488.27
# AC                    63       18311.84
# AP                    52       15871.03
# RR                    33        9862.34

# %%
all_data.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         128          1.0  5.0
# air_conditioning                   168          1.0  5.0
# art                                149          1.0  5.0
# arts_and_craftmanship               18          1.0  5.0
# audio                              238          1.0  5.0
# ...                                ...          ...  ...
# stationery                        1658          1.0  5.0
# tablets_printing_image              57          1.0  5.0
# telephony                         3012          1.0  5.0
# toys                              2748          1.0  5.0
# watches_gifts                     4012          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# **Convert all_data to .csv**

# %%
all_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana performa penjualan pada platform E-Commerce ?

# %%
monthly_df = all_data.resample(rule='M', on='order_approved_at').agg({
    "order_id": "nunique",
})
monthly_df.index = monthly_df.index.strftime('%B') #mengubah format order_approved_at menjadi Tahun-Bulan
monthly_df = monthly_df.reset_index()
monthly_df.rename(columns={
    "order_id": "order_count",
}, inplace=True)
monthly_df.head()
# Out:
#   order_approved_at  order_count
# 0         September            1
# 1           October          224
# 2          November            0
# 3          December            1
# 4           January          538

# %%
monthly_df = monthly_df.sort_values('order_count').drop_duplicates('order_approved_at', keep='last')

# %%
monthly_df.head()
# Out:
#    order_approved_at  order_count
# 12         September         3023
# 13           October         3264
# 15          December         4134
# 21              June         4379
# 22              July         4465

# %%
monthly_df.sort_values(by='order_count')
# Out:
#    order_approved_at  order_count
# 12         September         3023
# 13           October         3264
# 15          December         4134
# 21              June         4379
# 22              July         4465
# 23            August         4767
# 19             April         4782
# 17          February         4784
# 20               May         5072
# 16           January         5120
# 18             March         5152
# 14          November         5299

# %%
month_mapping = {
    "January": 1,
    "February": 2,
    "March": 3,
    "April": 4,
    "May": 5,
    "June": 6,
    "July": 7,
    "August": 8,
    "September": 9,
    "October": 10,
    "November": 11,
    "December": 12
}

monthly_df["month_numeric"] = monthly_df["order_approved_at"].map(month_mapping)
monthly_df = monthly_df.sort_values("month_numeric")
monthly_df = monthly_df.drop("month_numeric", axis=1)

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_df["order_approved_at"],
    monthly_df["order_count"],
    marker='o',
    linewidth=2,
    color="#FF9800"
)
plt.title("Number of Orders per Month (2018)", loc="center", fontsize=20)
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Pada grafik diatas bahwa terjadi penurunan signifikan pada bulan September dan mengalami penaikan yang signifikan pada bulan November.

# %% [markdown]
# ### Pertanyaan 2: Bagaimana tingkat kepuasan customer terhadap layanan kami?

# %%
review_scores = all_data['review_score'].value_counts().sort_values(ascending=False)

most_common_score = review_scores.idxmax()

sns.set(style="darkgrid")

plt.figure(figsize=(10, 5))
sns.barplot(x=review_scores.index,
            y=review_scores.values,
            order=review_scores.index,
            palette=["#8E7AB5" if score == most_common_score else "#E493B3" for score in review_scores.index]
            )

plt.title("Rating by customers for service", fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Count")
plt.xticks(fontsize=12)
plt.show()
# Out:
# <ipython-input-217-d3e597389969>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=review_scores.index,

# %% [markdown]
# ### Pertanyaan 3: Apa produk yang terlaris dan tidak ?

# %%
sum_order_items_df = all_data.groupby("product_category_name_english")["product_id"].count().reset_index()
sum_order_items_df = sum_order_items_df.rename(columns={"product_id": "products"})
sum_order_items_df = sum_order_items_df.sort_values(by="products", ascending=False)
sum_order_items_df = sum_order_items_df.head(10)

sum_order_items_df.head()
# Out:
#    product_category_name_english  products
# 7                 bed_bath_table      8365
# 43                 health_beauty      7173
# 65                sports_leisure      6461
# 39               furniture_decor      6223
# 15         computers_accessories      5707

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#C63D2F", "#E25E3E", "#FF9B50", "#FFBB5C", "#FFC26F"]

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk paling banyak terjual", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk paling sedikit terjual", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Produk paling banyak dan paling sedikit terjual", fontsize=20)
plt.show()
# Out:
# <ipython-input-213-065de48a5ab7>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# <ipython-input-213-065de48a5ab7>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### Pertanyaan 4: Bulan apa pengeluaran cuetomer terbanyak ?

# %%
monthly_spend_df = all_data.resample(rule='M', on='order_approved_at').agg({
    "payment_value":"sum"
})
monthly_spend_df.index = monthly_spend_df.index.strftime('%B') #mengubah format order_approved_at menjadi Tahun-Bulan
monthly_spend_df = monthly_spend_df.reset_index()
monthly_spend_df.rename(columns={
    "payment_value":"total_spend"
}, inplace=True)
monthly_spend_df.head()
# Out:
#   order_approved_at  total_spend
# 0         September         0.00
# 1           October     52189.82
# 2          November         0.00
# 3          December        19.62
# 4           January    135018.32

# %%
monthly_spend_df = monthly_spend_df.sort_values('total_spend').drop_duplicates('order_approved_at', keep='last')

# %%
monthly_spend_df.head()
# Out:
#    order_approved_at  total_spend
# 12         September    656092.79
# 15          December    784949.98
# 13           October    805432.32
# 23            August    908067.46
# 17          February    912512.02

# %%
monthly_spend_df.sort_values(by='total_spend')
# Out:
#    order_approved_at  total_spend
# 12         September    656092.79
# 15          December    784949.98
# 13           October    805432.32
# 23            August    908067.46
# 17          February    912512.02
# 21              June    928601.21
# 22              July    979238.57
# 16           January   1000407.16
# 19             April   1021325.03
# 18             March   1058931.64
# 20               May   1118333.82
# 14          November   1146778.76

# %%
monthly_spend_df["month_numeric"] = monthly_spend_df["order_approved_at"].map(month_mapping)
monthly_spend_df = monthly_spend_df.sort_values("month_numeric")
monthly_spend_df = monthly_spend_df.drop("month_numeric", axis=1)

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_spend_df["order_approved_at"],
    monthly_spend_df["total_spend"],
    marker='o',
    linewidth=2,
    color="#FC6736"
)
plt.title("Total customer spend money per Month (2018)", loc="center", fontsize=20)
plt.xticks(fontsize=10, rotation=25)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Pertanyaan 5: Dimana letak geografis customer terbanyak ?

# %%
other_state_geolocation = geo_df.groupby(['geolocation_zip_code_prefix'])['geolocation_state'].nunique().reset_index(name='count')
other_state_geolocation[other_state_geolocation['count']>= 2].shape
max_state = geo_df.groupby(['geolocation_zip_code_prefix','geolocation_state']).size().reset_index(name='count').drop_duplicates(subset = 'geolocation_zip_code_prefix').drop('count',axis=1)

# %%
geolocation_silver = geo_df.groupby(['geolocation_zip_code_prefix','geolocation_city','geolocation_state'])[['geolocation_lat','geolocation_lng']].median().reset_index()
geolocation_silver = geolocation_silver.merge(max_state,on=['geolocation_zip_code_prefix','geolocation_state'],how='inner')

# %%
customers_silver = customers_df.merge(geolocation_silver,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='inner')

# %%
customers_silver.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 1  8d401266c416fe74129569742199d75f  632b9f83894a36849b293ce84d62d399
# 2  4eb9eccb3b24a747f725dbee821a88b7  15f755c9f45213070f1b781ed78ea55c
# 3  3532ba38a3fd242259a514ac2b6ae6b6  4fa4365000c7090fcb8cad5713c6d3db
# 4  dc6c74aedc9324030804b25fa1021b17  6be824f2933ae5094244f962068ca531
#
#    customer_zip_code_prefix customer_city customer_state      status  \
# 0                      1151     sao paulo             SP      Active
# 1                      1151     sao paulo             SP      Active
# 2                      1151     sao paulo             SP      Active
# 3                      1151     sao paulo             SP      Active
# 4                      1151     sao paulo             SP  Non Active
#
#                            order_id order_status order_purchase_timestamp  \
# 0  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 1  494ccc8cd99c1f8293512733b50d1658    delivered      2018-02-09 10:47:02
# 2  cc6888dae9988bd99a2a190a7aa98431    delivered      2018-04-05 16:30:55
# 3  00b1cb0320190ca0daa2c88b35206009     canceled      2018-08-28 15:26:39
# 4                               NaN          NaN                      NaT
#
#     order_approved_at  ... review_score       review_comment_title  \
# 0 2018-05-20 16:19:10  ...          5.0                 no comment
# 1 2018-02-09 10:55:53  ...          5.0                 no comment
# 2 2018-04-05 16:49:49  ...          5.0                 no comment
# 3                 NaT  ...          1.0  Entregaram produto errado
# 4                 NaT  ...          NaN                        NaN
#
#                               review_comment_message  review_creation_date  \
# 0                                         no comment            2018-06-15
# 1                                         no comment            2018-03-07
# 2                                         no comment            2018-04-13
# 3  Comprei dois fones de ouvido com valor de R$ 5...            2018-08-28
# 4                                                NaN                   NaT
#
#    review_answer_timestamp geolocation_zip_code_prefix  geolocation_city  \
# 0      2018-06-15 12:10:59                        1151         sao paulo
# 1      2018-03-07 09:20:00                        1151         sao paulo
# 2      2018-04-13 19:10:20                        1151         sao paulo
# 3      2018-08-28 18:25:55                        1151         sao paulo
# 4                      NaT                        1151         sao paulo
#
#    geolocation_state geolocation_lat  geolocation_lng
# 0                 SP      -23.531294       -46.656404
# 1                 SP      -23.531294       -46.656404
# 2                 SP      -23.531294       -46.656404
# 3                 SP      -23.531294       -46.656404
# 4                 SP      -23.531294       -46.656404
#
# [5 rows x 29 columns]

# %%
customers_silver.to_csv("geolocation.csv", index=False)

# %%
def plot_brazil_map(data):
    brazil = mpimg.imread(urllib.request.urlopen('https://i.pinimg.com/originals/3a/0c/e1/3a0ce18b3c842748c255bc0aa445ad41.jpg'),'jpg')
    ax = data.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat", figsize=(10,10), alpha=0.3,s=0.3,c='maroon')
    plt.axis('off')
    plt.imshow(brazil, extent=[-73.98283055, -33.8,-33.75116944,5.4])
    plt.show()

# %%
plot_brazil_map(customers_silver.drop_duplicates(subset='customer_unique_id'))

# %% [markdown]
# **Kesimpulan** : Customer kebanyakan berasal dari negara bagian tenggara dan selatan.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Bagaimana performa penjualan pada platform E-Commerce ?
# - Bagaimana tingkat kepuasan customer terhadap layanan kami?
# - Apa produk yang terlaris dan tidak ?
# - Apa nama barang yang termasuk top 5 ?
# - Dimana letak geografis customer terbanyak ?

# %% [markdown]
#  Pada bulan Januari - Mei **performa penjualan pada platfrom  E-Commerce stabil** dan pada bulan Juni - Juli terjadi penurunan tetapi tidak signifikan.Pada bulan Agustus terjadi penaikan tetapi tidak signifikan sedangkan pada bulan September  terjadi penurunan sangat signifikan.Kemudian terjadi penaikan yang sangat signifikan pada bulan Oktober-November dan kembali menurun pada bulan Desember.

# %% [markdown]
# Kepuasan customer terhadap layanan yang diberikan terlihat dari visualisai data dengan banyaknya pemberian rating 5 dan rating 4 pada ururtan ke-2 terbanyak.

# %% [markdown]
# Dari hasil visualisasi menunjkan bahwa produk bed_bath_table yang sering dibeli customer dan produk auto tidak terlalu banyak dibeli.

# %% [markdown]
# Nama barang yang termasuk top 5 adalah

# %% [markdown]
# Pada grafik yang sudah dibuat, customer lebih banyak berada di negara bagian tenggara dan selatan serta lebih banyak customer di kota-kota yang merupakan ibu kota (São Paulo, Rio de Janeiro, Porto Alegre, dan lainnya)

# %%
all_data.to_csv("all_data.csv", index=False)
